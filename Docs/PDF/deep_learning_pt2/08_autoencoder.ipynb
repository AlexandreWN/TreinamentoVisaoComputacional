# %% [markdown]
# # Carregar dados
# * [download](https://storage.googleapis.com/tensorflow/tf-keras-datasets/minist.npz)
# * Mova o arquivo "mnist.npz" para a pasta do projeto
# * execute a celula abaixo
#
# obs: é possível carregar o dataset direto pelo keras da seguinte forma:
#
# `tf.keras.datasets.mnist.load_data(path="mnist.npz")`
#
# Contudo para evitarmos complicações em lidar com o proxy da Bosch, iremos realizar o download manual do dataset.

# %%
import numpy as np
with np.load("./data/mnist.npz", allow_pickle=True) as f:
    x_train, y_train = f['x_train'], f['y_train']
    x_test, y_test = f['x_test'], f['y_test']
print(f"{x_train.shape[0]} imagens de treino com resolução {x_train.shape[1]}x{x_train.shape[2]}")
print(f"shape: {x_train.shape}")
# Out:
# 60000 imagens de treino com resolução 28x28
# shape: (60000, 28, 28)

# %% [markdown]
# #### Visualização

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.gray)
    plt.xlabel(str(y_test[i]))
plt.show()

# %% [markdown]
# ### Pré-processamento
#
# Para pré-processamento das imagens iremos normalizar os valores das imagens entre 0 e 1.
# Outro fator relevante é que nosso dataset são imagens em tons de cinza, possuindo dimensões HW. Para padronizar as condições geralmente utilizadas com o keras precisamos incluir mais uma dimensão indicando a quantidade de canais: HWC = (28, 28, 1)

# %%
x_train = x_train / 255
x_test = x_test / 255

x_train = x_train[..., np.newaxis]  # np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = x_test[..., np.newaxis]

print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# ### Criação do modelo
# Para a criação do modelos iremos utilizar um modelo não sequencial com o propósito de facilitar a visualização de qual parte da rede é o encoder e qual parte será o decoder.

# %%
from tensorflow import keras
from tensorflow.keras import layers

input_img = keras.Input(shape=(28, 28, 1))
    
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)  # output (4, 4, 8)

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ### Callback para acompanhar as imagens geradas pelo nosso autoencoder durante o treinamento
# Como vimos em aulas passadas o Callback padrão do Keras salva apenas as métricas de treinamento, nesse caso queremos também observar a imagem gerada pelo autoencoder com o decorrer do treinamento

# %%
import io
import os

import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import Callback

# %%
class OutputViewer(Callback):
    def __init__(self, images, log_dir="./"):
        super().__init__()
        self._log_dir = log_dir
        self._file_writer = tf.summary.create_file_writer(os.path.join(log_dir, "images"))
        self._images = images


    @staticmethod
    def _plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image

    def _image_grid(self):
        """Return a 5x5 grid of the MNIST images as a matplotlib figure."""
        # Create a figure to contain the plot.
        figure = plt.figure(figsize=(10, 10))
        pred = self.model.predict(self._images)
        for i in range(25):
            # Start next subplot.
            plt.subplot(5, 5, i + 1)
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.imshow(pred[i], cmap=plt.cm.gray)

        return figure

    def on_epoch_end(self, epoch, logs=None):
        # Prepare the plot
        figure = self._image_grid()
        # Convert to image and log
        with self._file_writer.as_default():
            tf.summary.image("Generated data", OutputViewer._plot_to_image(figure), step=epoch)

# %%
output_viewer_callback = OutputViewer(x_test[:25], log_dir='./autoencoder4')
# tensorboard --logdir=./autoencoder3 --samples_per_plugin images=1000

# %% [markdown]
# ### Treinamento

# %%
from tensorflow.keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=200,
                steps_per_epoch=10,
                batch_size=128,
                shuffle=True,
                callbacks=[TensorBoard(log_dir='./autoencoder4'), output_viewer_callback])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 323ms/steposs: 0.67
# 10/10 [==============================] - 5s 406ms/step - loss: 0.6736
# Epoch 2/200
# 1/1 [==============================] - 0s 240ms/steposs: 0.54
# 10/10 [==============================] - 3s 327ms/step - loss: 0.5405
# Epoch 3/200
# 1/1 [==============================] - 0s 39ms/steploss: 0.47
# 10/10 [==============================] - 3s 307ms/step - loss: 0.4726
# Epoch 4/200
# 1/1 [==============================] - 0s 113ms/steposs: 0.41
# 10/10 [==============================] - 3s 353ms/step - loss: 0.4120
# Epoch 5/200
# 1/1 [==============================] - 1s 644ms/steposs: 0.34
# 10/10 [==============================] - 5s 545ms/step - loss: 0.3467
# Epoch 6/200
# 1/1 [==============================] - 0s 156ms/steposs: 0.29
# 10/10 [==============================] - 5s 472ms/step - loss: 0.2939
# Epoch 7/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.25
# 10/10 [==============================] - 2s 214ms/step - loss: 0.2599
# Epoch 8/200
# 1/1 [==============================] - 0s 104ms/steposs: 0.24
# 10/10 [==============================] - 2s 223ms/step - loss: 0.2467
# Epoch 9/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.23
# 10/10 [==============================] - 2s 248ms/step - loss: 0.2367
# Epoch 10/200
# 1/1 [==============================] - 0s 29ms/steploss: 0.22
# 10/10 [==============================] - 2s 206ms/step - loss: 0.2279
# Epoch 11/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.22
# 10/10 [==============================] - 2s 206ms/step - loss: 0.2253
# Epoch 12/200
# 1/1 [==============================] - 0s 147ms/steposs: 0.22
# 10/10 [==============================] - 2s 231ms/step - loss: 0.2203
# Epoch 13/200
# 1/1 [==============================] - 0s 55ms/steploss: 0.21
# 10/10 [==============================] - 3s 287ms/step - loss: 0.2136
# Epoch 14/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.21
# 10/10 [==============================] - 3s 267ms/step - loss: 0.2121
# Epoch 15/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.20
# 10/10 [==============================] - 3s 287ms/step - loss: 0.2080
# Epoch 16/200
# 1/1 [==============================] - 0s 61ms/steploss: 0.20
# 10/10 [==============================] - 2s 256ms/step - loss: 0.2037
# Epoch 17/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.19
# 10/10 [==============================] - 2s 214ms/step - loss: 0.1986
# Epoch 18/200
# 1/1 [==============================] - 0s 40ms/steploss: 0.19
# 10/10 [==============================] - 2s 214ms/step - loss: 0.1966
# Epoch 19/200
# 1/1 [==============================] - 0s 44ms/steploss: 0.19
# 10/10 [==============================] - 3s 270ms/step - loss: 0.1918
# Epoch 20/200
# 1/1 [==============================] - 0s 43ms/steploss: 0.19
# 10/10 [==============================] - 2s 235ms/step - loss: 0.1903
# Epoch 21/200
# 1/1 [==============================] - 0s 37ms/steploss: 0.18
# 10/10 [==============================] - 2s 211ms/step - loss: 0.1858
# Epoch 22/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.18
# 10/10 [==============================] - 2s 209ms/step - loss: 0.1800
# Epoch 23/200
# 1/1 [==============================] - 0s 92ms/steploss: 0.17
# 10/10 [==============================] - 2s 242ms/step - loss: 0.1790
# Epoch 24/200
# 1/1 [==============================] - 0s 104ms/steposs: 0.17
# 10/10 [==============================] - 3s 285ms/step - loss: 0.1764
# Epoch 25/200
# 1/1 [==============================] - 0s 43ms/steploss: 0.17
# 10/10 [==============================] - 3s 292ms/step - loss: 0.1728
# Epoch 26/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.17
# 10/10 [==============================] - 2s 209ms/step - loss: 0.1719
# Epoch 27/200
# 1/1 [==============================] - 0s 122ms/steposs: 0.17
# 10/10 [==============================] - 3s 363ms/step - loss: 0.1702
# Epoch 28/200
# 1/1 [==============================] - 0s 43ms/steploss: 0.17
# 10/10 [==============================] - 2s 211ms/step - loss: 0.1700
# Epoch 29/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.16
# 10/10 [==============================] - 2s 213ms/step - loss: 0.1675
# Epoch 30/200
# 1/1 [==============================] - 0s 45ms/steploss: 0.16
# 10/10 [==============================] - 2s 230ms/step - loss: 0.1672
# Epoch 31/200
# 1/1 [==============================] - 0s 47ms/steploss: 0.16
# Epoch 98/200
# 1/1 [==============================] - 0s 142ms/steposs: 0.12
# 10/10 [==============================] - 2s 230ms/step - loss: 0.1290
# Epoch 99/200
# 1/1 [==============================] - 0s 56ms/steploss: 0.12
# 10/10 [==============================] - 3s 269ms/step - loss: 0.1260
# Epoch 100/200
# 1/1 [==============================] - 0s 36ms/steploss: 0.12
# 10/10 [==============================] - 2s 199ms/step - loss: 0.1256
# Epoch 101/200
# 1/1 [==============================] - 0s 40ms/steploss: 0.12
# 10/10 [==============================] - 2s 210ms/step - loss: 0.1287
# Epoch 102/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.12
# 10/10 [==============================] - 2s 228ms/step - loss: 0.1276
# Epoch 103/200
# 1/1 [==============================] - 0s 40ms/steploss: 0.12
# 10/10 [==============================] - 2s 213ms/step - loss: 0.1269
# Epoch 104/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.12
# 10/10 [==============================] - 2s 210ms/step - loss: 0.1260
# Epoch 105/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.12
# 10/10 [==============================] - 2s 199ms/step - loss: 0.1278
# Epoch 106/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.12
# 10/10 [==============================] - 2s 196ms/step - loss: 0.1262
# Epoch 107/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.12
# 10/10 [==============================] - 2s 200ms/step - loss: 0.1267
# Epoch 108/200
# 1/1 [==============================] - 0s 36ms/steploss: 0.12
# 10/10 [==============================] - 2s 200ms/step - loss: 0.1269
# Epoch 109/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.12
# 10/10 [==============================] - 2s 198ms/step - loss: 0.1240
# Epoch 110/200
# 1/1 [==============================] - 0s 29ms/steploss: 0.12
# 10/10 [==============================] - 2s 201ms/step - loss: 0.1254
# Epoch 111/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.12
# 10/10 [==============================] - 2s 205ms/step - loss: 0.1271
# Epoch 112/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.12
# 10/10 [==============================] - 2s 227ms/step - loss: 0.1264
# Epoch 113/200
# 1/1 [==============================] - 0s 132ms/steposs: 0.12
# 10/10 [==============================] - 2s 250ms/step - loss: 0.1232
# Epoch 114/200
# 1/1 [==============================] - 0s 102ms/steposs: 0.12
# 10/10 [==============================] - 3s 361ms/step - loss: 0.1265
# Epoch 115/200
# 1/1 [==============================] - 0s 29ms/steploss: 0.12
# 10/10 [==============================] - 2s 201ms/step - loss: 0.1262
# Epoch 116/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.12
# 10/10 [==============================] - 2s 206ms/step - loss: 0.1240
# Epoch 117/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.12
# 10/10 [==============================] - 2s 198ms/step - loss: 0.1252
# Epoch 118/200
# 1/1 [==============================] - 0s 30ms/steploss: 0.12
# 10/10 [==============================] - 2s 198ms/step - loss: 0.1248
# Epoch 119/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.12
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1246
# Epoch 120/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.12
# 10/10 [==============================] - 2s 228ms/step - loss: 0.1255
# Epoch 121/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.12
# 10/10 [==============================] - 2s 214ms/step - loss: 0.1247
# Epoch 122/200
# 1/1 [==============================] - 0s 36ms/steploss: 0.12
# 10/10 [==============================] - 2s 208ms/step - loss: 0.1228
# Epoch 123/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.12
# 10/10 [==============================] - 2s 198ms/step - loss: 0.1231
# Epoch 124/200
# 1/1 [==============================] - 0s 30ms/steploss: 0.12
# 10/10 [==============================] - 2s 199ms/step - loss: 0.1220
# Epoch 125/200
# 1/1 [==============================] - 0s 111ms/steposs: 0.12
# 10/10 [==============================] - 2s 230ms/step - loss: 0.1222
# Epoch 126/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.12
# 10/10 [==============================] - 2s 199ms/step - loss: 0.1220
# Epoch 127/200
# 1/1 [==============================] - 0s 121ms/steposs: 0.12
# 10/10 [==============================] - 3s 264ms/step - loss: 0.1216
# Epoch 128/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.12
# 10/10 [==============================] - 2s 202ms/step - loss: 0.1226
# Epoch 129/200
# 1/1 [==============================] - 0s 117ms/steposs: 0.12
# 10/10 [==============================] - 3s 324ms/step - loss: 0.1214
# Epoch 130/200
# 1/1 [==============================] - 0s 32ms/steploss: 0.12
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1234
# Epoch 131/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.12
# 10/10 [==============================] - 2s 204ms/step - loss: 0.1227
# Epoch 132/200
# 1/1 [==============================] - 0s 48ms/steploss: 0.11
# 10/10 [==============================] - 2s 205ms/step - loss: 0.1196
# Epoch 133/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.12
# 10/10 [==============================] - 2s 199ms/step - loss: 0.1223
# Epoch 134/200
# 1/1 [==============================] - 0s 28ms/steploss: 0.12
# 10/10 [==============================] - 2s 204ms/step - loss: 0.1208
# Epoch 135/200
# 1/1 [==============================] - 0s 31ms/steploss: 0.11
# 10/10 [==============================] - 2s 205ms/step - loss: 0.1186
# Epoch 136/200
# 1/1 [==============================] - 0s 36ms/steploss: 0.12
# 10/10 [==============================] - 2s 198ms/step - loss: 0.1213
# Epoch 137/200
# 1/1 [==============================] - 0s 37ms/steploss: 0.11
# 10/10 [==============================] - 2s 201ms/step - loss: 0.1188
# Epoch 138/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.12
# 10/10 [==============================] - 2s 201ms/step - loss: 0.1200
# Epoch 139/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.11
# 10/10 [==============================] - 2s 214ms/step - loss: 0.1185
# Epoch 140/200
# 1/1 [==============================] - 0s 44ms/steploss: 0.12
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1201
# Epoch 141/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.11
# 10/10 [==============================] - 2s 206ms/step - loss: 0.1196
# 1/1 [==============================] - 0s 38ms/steploss: 0.11
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1139
# Epoch 187/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.11
# 10/10 [==============================] - 2s 221ms/step - loss: 0.1132
# Epoch 188/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.11
# 10/10 [==============================] - 2s 209ms/step - loss: 0.1147
# Epoch 189/200
# 1/1 [==============================] - 0s 30ms/steploss: 0.11
# 10/10 [==============================] - 2s 213ms/step - loss: 0.1126
# Epoch 190/200
# 1/1 [==============================] - 0s 49ms/steploss: 0.11
# 10/10 [==============================] - 5s 563ms/step - loss: 0.1148
# Epoch 191/200
# 1/1 [==============================] - 0s 120ms/steposs: 0.11
# 10/10 [==============================] - 3s 263ms/step - loss: 0.1134
# Epoch 192/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.11
# 10/10 [==============================] - 2s 213ms/step - loss: 0.1131
# Epoch 193/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.11
# 10/10 [==============================] - 2s 209ms/step - loss: 0.1132
# Epoch 194/200
# 1/1 [==============================] - 0s 37ms/steploss: 0.11
# 10/10 [==============================] - 2s 235ms/step - loss: 0.1133
# Epoch 195/200
# 1/1 [==============================] - 0s 38ms/steploss: 0.11
# 10/10 [==============================] - 2s 230ms/step - loss: 0.1122
# Epoch 196/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.11
# 10/10 [==============================] - 2s 220ms/step - loss: 0.1121
# Epoch 197/200
# 1/1 [==============================] - 0s 35ms/steploss: 0.11
# 10/10 [==============================] - 2s 217ms/step - loss: 0.1127
# Epoch 198/200
# 1/1 [==============================] - 0s 33ms/steploss: 0.11
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1117
# Epoch 199/200
# 1/1 [==============================] - 0s 34ms/steploss: 0.11
# 10/10 [==============================] - 2s 218ms/step - loss: 0.1120
# Epoch 200/200
# 1/1 [==============================] - 0s 37ms/steploss: 0.11
# 10/10 [==============================] - 2s 214ms/step - loss: 0.1144

# %% [markdown]
# ### Visualização dos resultados

# %%
decoded_imgs = autoencoder.predict(x_test)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(decoded_imgs[i], cmap=plt.cm.gray)
    plt.xlabel(str(y_test[i]))
plt.show()
# Out:
# 313/313 [==============================] - 3s 10ms/step

# %% [markdown]
# # Parte 2
#
# Nessa segunda parte iremos adcionar ruídos em nossas amostras e criaremos um autoencoder capaz de identificar e remover o ruído.
#
# ### Adição de ruído aos dados de treinamento

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
print(x_train_noisy.shape, x_train.shape)

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test_noisy[i], cmap=plt.cm.gray)
    plt.xlabel(str(y_test[i]))
plt.show()
# Out:
# (60000, 28, 28, 1) (60000, 28, 28, 1)

# %% [markdown]
# ## Criação de novo modelo para treino
#
# Podemos até utilizar o modelo previamente treinado, mas para garantirmos um modelo sem viés iremos criar um do zero.

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)  # output (4, 4, 8)

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=10,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='./autoencoder_noisy')])
# Out:
# Epoch 1/10
# 469/469 [==============================] - 72s 149ms/step - loss: 0.2678 - val_loss: 0.1873
# Epoch 2/10
# 469/469 [==============================] - 70s 150ms/step - loss: 0.1762 - val_loss: 0.1653
# Epoch 3/10
# 469/469 [==============================] - 62s 131ms/step - loss: 0.1604 - val_loss: 0.1542
# Epoch 4/10
# 469/469 [==============================] - 59s 127ms/step - loss: 0.1510 - val_loss: 0.1463
# Epoch 5/10
# 469/469 [==============================] - 60s 129ms/step - loss: 0.1449 - val_loss: 0.1414
# Epoch 6/10
# 469/469 [==============================] - 61s 131ms/step - loss: 0.1408 - val_loss: 0.1378
# Epoch 7/10
# 469/469 [==============================] - 59s 126ms/step - loss: 0.1375 - val_loss: 0.1357
# Epoch 8/10
# 469/469 [==============================] - 75s 160ms/step - loss: 0.1352 - val_loss: 0.1332
# Epoch 9/10
# 469/469 [==============================] - 63s 135ms/step - loss: 0.1333 - val_loss: 0.1308
# Epoch 10/10
# 469/469 [==============================] - 57s 121ms/step - loss: 0.1317 - val_loss: 0.1295

# %% [markdown]
# ### Visualização da remoção de ruídos pelo autoencoder

# %%
decoded_imgs = autoencoder.predict(x_test)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(decoded_imgs[i], cmap=plt.cm.gray)
    plt.xlabel(str(y_test[i]))
plt.show()
# Out:
# 313/313 [==============================] - 3s 9ms/step
